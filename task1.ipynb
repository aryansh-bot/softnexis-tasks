# %%
# Import Libraries
import pandas as pd

# Load Dataset
df = pd.read_csv("C:/Users/ary53/Downloads/sales_data_sample.csv", encoding="latin1")

# Display first 5 rows
print(df.head())

# Dataset Information
print(df.info())

# Shape of Dataset
print("Shape:", df.shape)

# Basic Statistics
print(df.describe(include='all'))
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
# Missing Values
print(df.isnull().sum())
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
# Fill missing numerical values
df.fillna(df.mean(numeric_only=True), inplace=True)

# Fill categorical values
df.fillna("Unknown", inplace=True)

# %%
# Check duplicates
print("Duplicate Rows:", df.duplicated().sum())

# Remove duplicates
df = df.drop_duplicates()

print("Shape after removing duplicates:", df.shape)
# Out:
# Duplicate Rows: 0
# Shape after removing duplicates: (2823, 25)

# %%
print(df["COUNTRY"].unique())

print(df["STATUS"].unique())

print(df["PRODUCTLINE"].unique())
# Out:
# ['USA' 'France' 'Norway' 'Australia' 'Finland' 'Austria' 'UK' 'Spain'
#  'Sweden' 'Singapore' 'Canada' 'Japan' 'Italy' 'Denmark' 'Belgium'
#  'Philippines' 'Germany' 'Switzerland' 'Ireland']
# ['Shipped' 'Disputed' 'In Process' 'Cancelled' 'On Hold' 'Resolved']
# ['Motorcycles' 'Classic Cars' 'Trucks and Buses' 'Vintage Cars' 'Planes'
#  'Ships' 'Trains']

# %%
df = df.drop(columns=["ADDRESSLINE2", "PHONE"])

# %%
df.rename(columns={
    "ORDERNUMBER":"Order_Number",
    "QUANTITYORDERED":"Quantity",
    "PRICEEACH":"Unit_Price",
    "SALES":"Sales"
}, inplace=True)

# %%
df = df[
[
"Order_Number",
"ORDERDATE",
"CUSTOMERNAME",
"PRODUCTLINE",
"Quantity",
"Unit_Price",
"Sales",
"COUNTRY",
"STATUS"
]
]

# %%
print(df.dtypes)
# Out:
# Order_Number      int64
# ORDERDATE        object
# CUSTOMERNAME     object
# PRODUCTLINE      object
# Quantity          int64
# Unit_Price      float64
# Sales           float64
# COUNTRY          object
# STATUS           object
# dtype: object

# %%
df["ORDERDATE"] = pd.to_datetime(df["ORDERDATE"])

# %%
df = df[df["Quantity"] > 0]

df = df[df["Sales"] > 0]

# %%
print(df.info())

print(df.head())

print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_Number  2823 non-null   int64
#  1   ORDERDATE     2823 non-null   datetime64[ns]
#  2   CUSTOMERNAME  2823 non-null   object
#  3   PRODUCTLINE   2823 non-null   object
#  4   Quantity      2823 non-null   int64
#  5   Unit_Price    2823 non-null   float64
#  6   Sales         2823 non-null   float64
#  7   COUNTRY       2823 non-null   object
#  8   STATUS        2823 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 198.6+ KB
# None
#    Order_Number  ORDERDATE              CUSTOMERNAME  PRODUCTLINE  Quantity  \
# 0         10107 2003-02-24         Land of Toys Inc.  Motorcycles        30
# 1         10121 2003-05-07        Reims Collectables  Motorcycles        34
# ...

# %%
df.to_csv("cleaned_sales_data.csv", index=False)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("C:/Users/ary53/Downloads/sales_data_sample.csv", encoding="latin1")

# Display first 5 rows
print(df.head())

# Dataset information
print(df.info())

# Shape of dataset
print("Shape:", df.shape)

# Basic statistics
print(df.describe(include='all'))
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
# Check missing values in each column
print(df.isna().sum())

# Percentage of missing values
missing_percentage = (df.isna().sum() / len(df)) * 100
print(missing_percentage)
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64
# ORDERNUMBER          0.000000
# QUANTITYORDERED      0.000000
# PRICEEACH            0.000000
# ORDERLINENUMBER      0.000000
# SALES                0.000000
# ORDERDATE            0.000000
# STATUS               0.000000
# QTR_ID               0.000000
# MONTH_ID             0.000000
# ...

# %%
threshold = 0.70

df = df.loc[:, df.isnull().mean() < threshold]

# %%
df = df.dropna(thresh=int(df.shape[1] * 0.7))

# %%
numeric_columns = df.select_dtypes(include=['int64','float64']).columns

for col in numeric_columns:
    df[col].fillna(df[col].mean(), inplace=True)

# %%
numeric_columns = df.select_dtypes(include=['int64','float64']).columns

for col in numeric_columns:
    df[col].fillna(df[col].mean(), inplace=True)

# %%
categorical_columns = df.select_dtypes(include='object').columns

for col in categorical_columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
print(df.isna().sum())
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# YEAR_ID             0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# PHONE               0
# ADDRESSLINE1        0
# CITY                0
# STATE               0
# POSTALCODE          0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
df["ORDERDATE"] = pd.to_datetime(df["ORDERDATE"])

# %%
text_columns = ["CUSTOMERNAME","COUNTRY","PRODUCTLINE","STATUS"]

for col in text_columns:
    df[col] = df[col].str.lower()

# %%
for col in text_columns:
    df[col] = df[col].str.strip()

# %%
df["COUNTRY"] = df["COUNTRY"].replace({
    "usa":"united states",
    "u.s.a":"united states",
    "uk":"united kingdom"
})

# %%
df["STATUS"] = df["STATUS"].replace({
    "shipped ":"shipped",
    "cancelled ":"cancelled"
})

# %%
print(df.head())
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...             PHONE  \
# 0 2003-02-24  shipped       1         2     2003  ...        2125557818
# 1 2003-05-07  shipped       2         5     2003  ...        26.47.1555
# 2 2003-07-01  shipped       3         7     2003  ...  +33 1 46 62 7555
# 3 2003-08-25  shipped       3         8     2003  ...        6265557265
# 4 2003-10-10  shipped       4        10     2003  ...        6505551386
#
#                     ADDRESSLINE1           CITY STATE POSTALCODE  \
# ...

# %%
df.to_csv("cleaned_sales_data.csv", index=False)

print("Final cleaned dataset saved successfully.")
# Out:
# Final cleaned dataset saved successfully.
